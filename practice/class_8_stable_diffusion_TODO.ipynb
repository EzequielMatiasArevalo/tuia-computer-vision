# %% [markdown]
# # Clase 8 — Stable Diffusion (practica)
#
# > **TODO — esta clase todavia no tiene practica.**
#
# Teoria: [`colab/class8_stable_diffusion_course.ipynb`](../colab/class8_stable_diffusion_course.ipynb) · [Abrir en Colab](https://colab.research.google.com/github/EzequielMatiasArevalo/tuia-computer-vision/blob/main/colab/class8_stable_diffusion_course.ipynb)
#
# Difusion latente en la practica. La teoria ya trae seis practicos armados; esta notebook deberia quedarse con los ejercicios y dejar la explicacion en la teorica.
#
# ## Contenido previsto
#
# - Text-to-image con `stable-diffusion-v1-5`: efecto del *seed*, de los pasos y del CFG.
# - Image-to-image e inpainting con `stable-diffusion-inpainting`.
# - Prompt engineering: anatomia de un prompt, *negative prompt* como el ∅ de la guia sin clasificador.
# - Visualizar el proceso de *denoising* paso a paso.
# - LoRA: cargar un adaptador y medir que cambia respecto del modelo base.
# - ControlNet: condicionamiento estructural a partir de bordes o pose.
# - Cierre: que apaga `safety_checker=None` y como se declara contenido generado (C2PA / watermarking).
#
# ## Notas
#
# - Necesita GPU (T4 o mejor).
# - Las descargas de pesos son pesadas: conviene cachearlas al principio.
