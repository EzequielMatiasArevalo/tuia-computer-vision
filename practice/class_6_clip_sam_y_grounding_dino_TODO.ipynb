# %% [markdown]
# # Clase 6 — CLIP, SAM 3 y Grounding DINO (practica)
#
# > **TODO — esta clase todavia no tiene practica.**
#
# Teoria: [`colab/class_6_Clip_and_SAM.ipynb`](../colab/class_6_Clip_and_SAM.ipynb) · [Abrir en Colab](https://colab.research.google.com/github/EzequielMatiasArevalo/tuia-computer-vision/blob/main/colab/class_6_Clip_and_SAM.ipynb)
#
# Vision promptable y de vocabulario abierto: modelos que se dirigen con texto en lugar de reentrenarse.
#
# ## Contenido previsto
#
# - CLIP: clasificacion zero-shot y como cambia el resultado segun como se escribe el *prompt*.
# - CLIP: retrieval texto -> imagen sobre una galeria propia, con la matriz contrastiva a la vista.
# - SAM 3: segmentacion por concepto (PCS) con prompts de texto y exploracion de vocabulario abierto.
# - SAM 3: tracking en video con IDs consistentes y export a mp4.
# - Grounding DINO: deteccion open-vocabulary y comparacion contra un detector de clases cerradas.
# - Ejercicio de cierre: donde falla cada uno de los tres y por que.
#
# ## Notas
#
# - Necesita GPU.
# - `facebook/sam3` es un repo *gated* en Hugging Face: hay que pedir acceso y autenticarse antes de correrlo.
# - La parte de tracking se solapa con la practica de la clase 7 — conviene no repetir el mismo video.
