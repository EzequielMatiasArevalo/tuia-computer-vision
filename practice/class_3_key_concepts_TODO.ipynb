# %% [markdown]
# # Clase 3 — Anchors, NMS, metricas y funciones de perdida (practica)
#
# > **TODO — esta clase todavia no tiene practica.**
#
# Teoria: [`colab/class_3_Key_Concepts_for_Deep_Learning_CV.ipynb`](../colab/class_3_Key_Concepts_for_Deep_Learning_CV.ipynb) · [Abrir en Colab](https://colab.research.google.com/github/EzequielMatiasArevalo/tuia-computer-vision/blob/main/colab/class_3_Key_Concepts_for_Deep_Learning_CV.ipynb)
#
# La clase de mecanica: todo lo que hace un detector entre los *features* y las cajas en pantalla, mas las perdidas que lo entrenan. La teoria ya trae celdas ejecutables; la practica deberia hacerlas construir cada pieza a mano antes de usar la version de la libreria.
#
# ## Contenido previsto
#
# - IoU implementado desde cero y las reglas de asignacion del RPN de Faster R-CNN.
# - Anchor boxes: generacion de la grilla, encoding/decoding de offsets, y comparacion contra detectores *anchor-free*.
# - RoI Pooling vs RoI Align — reproducir el error de alineacion que RoI Align corrige.
# - NMS desde cero sobre un ejemplo sintetico, y comparacion contra `torchvision.ops.nms`.
# - Metricas: accuracy, precision, recall, F1, mAP@50 y mAP@[50:95] calculadas a mano y con `torchmetrics`.
# - Perdidas de clasificacion: cross-entropy vs focal loss sobre un dataset desbalanceado.
# - Perdidas de caja: L2, Smooth L1, IoU, GIoU, DIoU, CIoU — incluyendo el caso donde la IoU loss muere con cajas disjuntas.
#
# ## Notas
#
# - Corre en CPU sin problema; no necesita GPU.
