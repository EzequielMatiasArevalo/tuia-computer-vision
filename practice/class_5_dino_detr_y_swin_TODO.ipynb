# %% [markdown]
# # Clase 5 — DINOv2/v3, DETR y Swin (practica)
#
# > **TODO — esta clase todavia no tiene practica.**
#
# Teoria: [`colab/class_5_Dino_Detr_and_Swin.ipynb`](../colab/class_5_Dino_Detr_and_Swin.ipynb) · [Abrir en Colab](https://colab.research.google.com/github/EzequielMatiasArevalo/tuia-computer-vision/blob/main/colab/class_5_Dino_Detr_and_Swin.ipynb)
#
# Transformers de vision aplicados: features auto-supervisados, atencion por ventanas y deteccion como *set prediction*.
#
# ## Contenido previsto
#
# - DINOv2 como extractor: PCA y K-Means sobre los *patch tokens* para segmentar sin etiquetas.
# - Fine-tuning de DINOv2 con una cabeza propia sobre un dataset chico.
# - DINOv3: efecto de los *register tokens* en los mapas de atencion; comparar backbone ConvNeXt vs ViT.
# - Swin: visualizar el particionado en ventanas y el desplazamiento (W-MSA / SW-MSA); fine-tuning en clasificacion.
# - DETR: *object queries*, matching bipartito (Hungaro) y segmentacion panoptica sobre COCO.
#
# ## Notas
#
# - Necesita GPU (T4 alcanza).
# - Los pesos de DINOv3 requieren aceptar la licencia en Hugging Face.
